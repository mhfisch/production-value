# %% [markdown]
# I want to write a script that takes a list of Wikipedia category pages for record producers and adds all of the featurized audio data and metadata into a mongodb.

# %%
# Standard Imports

import numpy as np
import pandas as pd
import os
import sys
from collections import defaultdict
from importlib import reload
from bs4 import BeautifulSoup
import requests

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# Load MongoDB

from pymongo import MongoClient
client = MongoClient()
# Access/Initiate Database
db = client['producer_db']
# Access/Initiate Table
tab = db['songs']

# %%
# Authorize Spotify API

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = os.environ['SPOTIFY_CLIENT_ID']
client_secret = os.environ['SPOTIFY_CLIENT_SECRET']
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Import Custom Webscraping Modules

import src.wiki_scraping as wiki_scraping

# %%
reload(wiki_scraping)
# Out:
# <module 'src.wiki_scraping' from '/Users/Maxwell/galvanize/production-value/src/wiki_scraping.py'>

# %%
cat_url_list = ['https://en.wikipedia.org/wiki/Category:Song_recordings_produced_by_George_Martin',
                'https://en.wikipedia.org/wiki/Category:Song_recordings_produced_by_Dr._Dre',
                'https://en.wikipedia.org/wiki/Category:Song_recordings_produced_by_Rick_Rubin',
                'https://en.wikipedia.org/wiki/Category:Song_recordings_produced_by_Brian_Eno',
                'https://en.wikipedia.org/wiki/Category:Song_recordings_produced_by_Stock_Aitken_Waterman']

collection = db.tab

# %%
def load_producers(cat_url_list, collection, sp):
    
    for cat_url in cat_url_list:

        #Extract Producer Name
        html = requests.get(cat_url).content
        soup = BeautifulSoup(html, 'html.parser')
        producer = soup.find_all('h1', {'id':"firstHeading"})[0].text.split('by ')[-1]

        print('-'*20)
        print('PRODUCER: {}'.format(producer))
        print('-'*20)
        print()

        #Scrape Wikipedia Page for Songs and get spotify track id's
        print('Scraping Wikipedia')
        spotify_info = wiki_scraping.get_spotify_info_from_wiki(cat_url, sp)

        print('Example data:')
        for i in range(5):
            print(spotify_info[i])
        print()

        print('Extracting Audio Analysis...')
        print()

        idx_list = []

        #Use SpotiPy to access song featurized data
        for track, artist, album, song_id, spotify_track, spotify_artist in spotify_info:
            print('Importing {} by {}...'.format(track,artist))
            query = 'track:{} artist:{}'.format(track,artist)
            result = sp.search(q=query, type='track')
            song_id = result['tracks']['items'][0]['id']
            song_info = sp.track(song_id)
            song_analysis = sp.audio_analysis(song_id)
            song_features = sp.audio_features(song_id)


            #Add featurized data to MongoDB
            new_entry = {'track':track,
                         'artist':artist,
                         'album':album,
                         'producer':producer,
                         'spotify_id':song_id,
                         'track_info':song_info,
                         'audio_analysis':song_analysis,
                         'audio_features':song_features}

            idx = collection.insert_one(new_entry)
            idx_list.append(idx)

            print('Import Complete.')
            print()
            
    return idx_list

# %%
idx_list = load_producers(cat_url_list, collection, sp)
# Out:
# --------------------
# PRODUCER: George Martin
# --------------------
#
# Scraping Wikipedia
# Scraping Wikipedia
#
# Querying Spotify API
#
# Example data:
# ('12-Bar Original', 'the Beatles', 'Anthology 2', '2HvTGx5fzFGpHSyRNvXd9T', '12 Bar Original - Anthology 2 Version', 'The Beatles')
# ('Across the Universe', 'the Beatles', "No One's Gonna Change Our World", '4dkoqJrP0L8FXftrMZongF', 'Across The Universe - Remastered 2009', 'The Beatles')
# ('Act Naturally', 'Buck Owens and the Buckaroos', 'The Best of Buck Owens', '2LClPTK0FNl4AnOfKUJBQw', 'Act Naturally (Live)', 'Buck Owens & The Buckaroos')
# ('Alfie', 'Cilla Black', 'Cilla Black singles chronology', '2IqtBxwRgNOt7YWMmulrUZ', 'Alfie - 2003 Remaster', 'Cilla Black')
# ("All I've Got to Do", 'the Beatles', 'With the Beatles', '5tztLBvTlNC15Np2tnQ5Ll', "All I've Got To Do - Remastered 2009", 'The Beatles')
#
# Extracting Audio Analysis...
#
# Importing 12-Bar Original by the Beatles...
# Import Complete.
#
# Importing Across the Universe by the Beatles...
# Import Complete.
#
# Importing Act Naturally by Buck Owens and the Buckaroos...
# Import Complete.
#
# Importing Alfie by Cilla Black...
# Import Complete.
#
# Importing All I've Got to Do by the Beatles...
# Import Complete.
#
# Importing All My Loving by the Beatles...
# Import Complete.
#
# Importing All Together Now by the Beatles...
# Import Complete.
#
# Importing All You Need Is Love by the Beatles...
# Import Complete.
#
# Importing Amber Cascades by America...
# Import Complete.
#
# Importing And I Love Her by the Beatles...
# Import Complete.
#
# Importing And Your Bird Can Sing by the Beatles...
# Import Complete.
#
# Importing Another Girl by the Beatles...
# Import Complete.
#
# Importing Any Time at All by the Beatles...
# Import Complete.
#
# Importing Anyone Who Had a Heart by Dionne Warwick...
# Import Complete.
#
# Importing Ask Me Why by the Beatles...
# Import Complete.
#
# Importing Baby It's You by The Shirelles...
# Import Complete.
#
# Importing Back in the U.S.S.R. by the Beatles...
# Import Complete.
#
# Importing Bad Boy by Larry Williams...
# Import Complete.
#
# Importing The Ballad of John and Yoko by the Beatles...
# Import Complete.
#
# Importing Because by the Beatles...
# Import Complete.
#
# Importing Being for the Benefit of Mr. Kite! by the Beatles...
# Import Complete.
#
# Importing The Best of Me by Cliff Richard...
# Import Complete.
#
# Importing Birthday by the Beatles...
# Import Complete.
#
# Importing Blackbird by the Beatles...
# Import Complete.
#
# Importing Blue Jay Way by the Beatles...
# Import Complete.
#
# Importing Boys by the Beatles...
# Import Complete.
#
# Importing Calico Skies by Paul McCartney...
# Import Complete.
#
# Importing Can't Buy Me Love by the Beatles...
# Import Complete.
#
# Importing Carol by Chuck Berry...
# Import Complete.
#
# Importing Carry That Weight by the Beatles...
# Import Complete.
#
# Importing Chains by The Cookies...
# Import Complete.
#
# Importing Clarabella by The Beatles...
# Import Complete.
#
# Importing Come Together by the Beatles...
# Import Complete.
#
# Importing The Continuing Story of Bungalow Bill by the Beatles...
# Import Complete.
#
# Importing Cry Baby Cry by the Beatles...
# Import Complete.
#
# Importing Crying, Waiting, Hoping by Buddy Holly...
# Import Complete.
#
# Importing A Day in the Life by the Beatles...
# Import Complete.
#
# Importing Day Tripper by the Beatles...
# Import Complete.
#
# Importing Dear Prudence by the Beatles...
# Import Complete.
#
# Importing Dizzy Miss Lizzy by Larry Williams...
# Import Complete.
#
# Importing Do You Want to Know a Secret by the Beatles...
# Import Complete.
#
# Importing Doctor Robert by the Beatles...
# Import Complete.
#
# Importing Don't Pass Me By by the Beatles...
# Import Complete.
#
# Importing Drive My Car by the Beatles...
# Import Complete.
#
# Importing Eight Days a Week by the Beatles...
# Import Complete.
#
# Importing Eleanor Rigby by the Beatles...
# Import Complete.
#
# Importing The End by the Beatles...
# Import Complete.
#
# Importing Every Little Thing by the Beatles...
# Import Complete.
#
# Importing Everybody's Trying to Be My Baby by the Beatles...
# Import Complete.
#
# Importing Everything Works if You Let It by Cheap Trick...
# Import Complete.
#
# Importing Ferry Cross the Mersey by Gerry and the Pacemakers...
# Import Complete.
#
# Importing Fixing a Hole by the Beatles...
# Import Complete.
#
# Importing Flying by the Beatles...
# Import Complete.
#
# Importing The Fool on the Hill by the Beatles...
# Import Complete.
#
# Importing For No One by the Beatles...
# Import Complete.
#
# Importing Getting Better by the Beatles...
# Import Complete.
#
# Importing Girl by the Beatles...
# Import Complete.
#
# Importing Glass Onion by the Beatles...
# Import Complete.
#
# Importing Golden Slumbers by the Beatles...
# Import Complete.
#
# Importing Good Day Sunshine by the Beatles...
# Import Complete.
#
# Importing Good Morning Good Morning by the Beatles...
# Import Complete.
#
# Importing Good Night by the Beatles...
# Import Complete.
#
# Importing Got to Get You into My Life by the Beatles...
# Import Complete.
#
# Importing A Hard Day's Night by the Beatles...
# Import Complete.
#
# Importing Hello Little Girl by The Fourmost...
# Import Complete.
#
# Importing Hello, Goodbye by the Beatles...
# Import Complete.
#
# Importing Help! by the Beatles...
# Import Complete.
#
# Importing Helter Skelter by the Beatles...
# Import Complete.
#
# Importing Her Majesty by the Beatles...
# Import Complete.
#
# Importing Here Comes the Sun by the Beatles...
# Import Complete.
#
# Importing Here Today by Paul McCartney...
# Import Complete.
#
# Importing Here, There and Everywhere by the Beatles...
# Import Complete.
#
# Importing Hey Bulldog by the Beatles...
# Import Complete.
#
# Importing Hey Jude by the Beatles...
# Import Complete.
#
# Importing Hey-Hey-Hey-Hey by Little Richard...
# Import Complete.
#
# Importing Hold Me Tight by the Beatles...
# Import Complete.
#
# Importing Honey Pie by the Beatles...
# Import Complete.
#
# Importing How Do You Do It? by Gerry and the Pacemakers...
# Import Complete.
#
# Importing Hymn by Ultravox...
# Import Complete.
#
# Importing I Am the Walrus by the Beatles...
# Import Complete.
#
# Importing I Don't Want to Spoil the Party by the Beatles...
# Import Complete.
#
# Importing I Feel Fine by the Beatles...
# Import Complete.
#
# Importing I Got to Find My Baby by The Beatles...
# Import Complete.
#
# Importing I Just Don't Understand by Ann-Margret...
# Import Complete.
#
# Importing I Like It by Gerry and the Pacemakers...
# Import Complete.
#
# Importing I Need You by the Beatles...
# Import Complete.
#
# Importing I Saw Her Standing There by the Beatles...
# Import Complete.
#
# Importing I Should Have Known Better by the Beatles...
# Import Complete.
#
# Importing I Wanna Be Your Man by the Rolling Stones...
# Import Complete.
#
# Importing I Want to Hold Your Hand by the Beatles...
# Import Complete.
#
# Importing I Want to Tell You by the Beatles...
# Import Complete.
#
# Importing I Want You (She's So Heavy) by the Beatles...
# Import Complete.
#
# Importing I Will by the Beatles...
# Import Complete.
#
# Importing If I Fell by the Beatles...
# Import Complete.
#
# Importing If I Needed Someone by the Beatles...
# Import Complete.
#
# Importing If I Thought You'd Ever Change Your Mind by Agnetha Fältskog...
# Import Complete.
#
# Importing If You've Got Trouble by the Beatles...
# Import Complete.
#
# Importing In My Life by the Beatles...
# Import Complete.
#
# Importing It Won't Be Long by the Beatles...
# Import Complete.
#
# Importing Julia by the Beatles...
# Import Complete.
#
# Importing Kansas City by Wilbert Harrison...
# Import Complete.
#
# Importing Keep Your Hands off My Baby by Little Eva...
# Import Complete.
#
# Importing Let It Be by the Beatles...
# Import Complete.
#
# Importing Little Child by the Beatles...
# Import Complete.
#
# Importing Live and Let Die by Wings...
# Import Complete.
#
# Importing Lonely People by America...
# Import Complete.
#
# Importing Long Tall Sally by Little Richard...
# Import Complete.
#
# Importing Long, Long, Long by the Beatles...
# Import Complete.
#
# Importing Love Me Do by the Beatles...
# Import Complete.
#
# Importing Love You To by the Beatles...
# Import Complete.
#
# Importing Lovely Rita by the Beatles...
# Import Complete.
#
# Importing Lucy in the Sky with Diamonds by the Beatles...
# Import Complete.
#
# Importing Magical Mystery Tour by the Beatles...
# Import Complete.
#
# Importing Martha My Dear by the Beatles...
# Import Complete.
#
# Importing Matchbox by Carl Perkins...
# Import Complete.
#
# Importing Mean Mr. Mustard by the Beatles...
# Import Complete.
#
# Importing Memphis, Tennessee by Chuck Berry...
# Import Complete.
#
# Importing Michelle by the Beatles...
# Import Complete.
#
# Importing Misery by the Beatles...
# Import Complete.
#
# Importing Money (That's What I Want) by Barrett Strong...
# Import Complete.
#
# Importing Morning Desire by Kenny Rogers...
# Import Complete.
#
# Importing Mother Nature's Son by the Beatles...
# Import Complete.
#
# Importing Mr. Moonlight by the Beatles...
# Import Complete.
#
# Importing The Night Before by the Beatles...
# Import Complete.
#
# Importing No More Lonely Nights by Paul McCartney...
# Import Complete.
#
# Importing No Reply by the Beatles...
# Import Complete.
#
# Importing Norwegian Wood (This Bird Has Flown) by the Beatles...
# Import Complete.
#
# Importing Not A Second Time by the Beatles...
# Import Complete.
#
# Importing Not Guilty by George Harrison...
# Import Complete.
#
# Importing Nowhere Man by the Beatles...
# Import Complete.
#
# --------------------
# PRODUCER: Dr. Dre
# --------------------
#
# Scraping Wikipedia
# Scraping Wikipedia
#
# Querying Spotify API
#
# Example data:
# ('3 a.m.', 'Eminem', 'Relapse', '7Djpvy4lZJNI8rTOVLf1H7', '3 a.m.', 'Eminem')
# ("100 Miles and Runnin'", 'N.W.A', "100 Miles and Runnin'", '7Fr7IW6tm3DvGIJT1T6NXO', "100 Miles And Runnin'", 'N.W.A.')
# ('Ass Like That', 'Eminem', 'Encore', '4gXdMZkBN1neE9nX6yRALa', 'Ass Like That', 'Eminem')
# ('Been There, Done That', 'Dr. Dre', 'Dr. Dre Presents the Aftermath', '7i1nzuzVU0y6XzGdVMJDoI', 'Been There Done That', 'Dr. Dre')
# ('Boyz-n-the-Hood', 'Eazy-E', 'N.W.A. and the Posse', '4SZ3B3y1TbwTK4OIXMOVEy', 'Boyz-N-The-Hood', 'Eazy-E')
#
# Extracting Audio Analysis...
#
# Importing 3 a.m. by Eminem...
# Import Complete.
#
# Importing 100 Miles and Runnin' by N.W.A...
# Import Complete.
#
# Importing Ass Like That by Eminem...
# Import Complete.
#
# Importing Been There, Done That by Dr. Dre...
# Import Complete.
#
# Importing Boyz-n-the-Hood by Eazy-E...
# Import Complete.
#
# Importing Break Ya Neck by Busta Rhymes...
# Import Complete.
#
# Importing Business by Eminem...
# Import Complete.
#
# Importing Eazy-Duz-It by Eazy-E...
# Import Complete.
#
# Importing Eazy-er Said Than Dunn by Eazy-E...
# Import Complete.
#
# Importing Express Yourself by N.W.A...
# Import Complete.
#
# Importing Family Affair by Mary J. Blige...
# Import Complete.
#
# Importing Fast Lane by Bilal...
# Import Complete.
#
# Importing Fight Music by D12...
# Import Complete.
#
# Importing The Formula by The D.O.C....
# Import Complete.
#
# Importing Fuck tha Police by N.W.A...
# Import Complete.
#
# Importing Gangsta Gangsta by N.W.A...
# Import Complete.
#
# Importing Gin and Juice by Snoop Doggy Dogg...
# Import Complete.
#
# Importing Higher by The Game...
# Import Complete.
#
# Importing How We Do by The Game featuring 50 Cent...
# Import Complete.
#
# Importing Hurt Again by Mary J. Blige...
# Import Complete.
#
# Importing I Get It In by 50 Cent...
# Import Complete.
#
# Importing I Wanna Rock by Snoop Dogg...
# Import Complete.
#
# Importing If I Can't by 50 Cent...
# Import Complete.
#
# Importing In da Club by 50 Cent...
# Import Complete.
#
# Importing Just Lose It by Eminem...
# Import Complete.
#
# Importing Keep Their Heads Ringin' by Dr. Dre...
# Import Complete.
#
# Importing Like Dat by Stat Quo...
# Import Complete.
#
# Importing Love by Musiq Soulchild...
# Import Complete.
#
# Importing Mosh by Eminem...
# Import Complete.
#
# Importing Murder Rap by Above the Law...
# Import Complete.
#
# Importing Music Box by Eminem...
# Import Complete.
#
# Importing My Name Is by Eminem...
# Import Complete.
#
# Importing New Day by Alicia Keys...
# Import Complete.
#
# Importing OK, You're Right by 50 Cent...
# Import Complete.
#
# Importing Panic Zone by N.W.A...
# Import Complete.
#
# Importing Poppin' Them Thangs by G-Unit...
# Import Complete.
#
# Importing The Real Slim Shady by Eminem...
# Import Complete.
#
# Importing Satisfaction by Eve...
# Import Complete.
#
# Importing Straight Outta Compton' by N.W.A...
# Import Complete.
#
# Importing Straight to the Bank by 50 Cent...
# Import Complete.
#
# Importing The Watcher by Dr. Dre...
# Import Complete.
#
# Importing We Made You by Eminem...
# Import Complete.
#
# Importing X by Xzibit...
# Import Complete.
#
# --------------------
# PRODUCER: Rick Rubin
# --------------------
#
# Scraping Wikipedia
# Scraping Wikipedia
#
# Querying Spotify API
#
# Example data:
# ('99 Problems', 'Jay-Z', 'The Black Album', '65eohvrL4ttjA7EfFkQOhX', 'Points Of Authority / 99 Problems / One Step Closer', 'JAY Z')
# ('The Adventures of Rain Dance Maggie', 'Red Hot Chili Peppers', "I'm with You", '0PgNhIg5n0UAOBVn43b8b6', 'The Adventures Of Rain Dance Maggie', 'Red Hot Chili Peppers')
# ('Aerials', 'System of a Down', 'Toxicity', '4e9eGQYsOiBcftrWXwsVco', 'Aerials', 'System Of A Down')
# ('Aeroplane', 'Red Hot Chili Peppers', 'One Hot Minute', '0VLdJcQUsqHBBwqPp4CIKJ', 'Aeroplane', 'Red Hot Chili Peppers')
# ('All Nightmare Long', 'Metallica', 'Death Magnetic', '5w3TTTAo6DIEjQYO3vKZq0', 'All Nightmare Long', 'Metallica')
#
# Extracting Audio Analysis...
#
# Importing 99 Problems by Jay-Z...
# Import Complete.
#
# Importing The Adventures of Rain Dance Maggie by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Aerials by System of a Down...
# Import Complete.
#
# Importing Aeroplane by Red Hot Chili Peppers...
# Import Complete.
#
# Importing All Nightmare Long by Metallica...
# Import Complete.
#
# Importing All Wrong by God Lives Underwater...
# Import Complete.
#
# Importing Angel of Death by Slayer...
# Import Complete.
#
# Importing Around the World by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Baby Got Back by Sir Mix-a-Lot...
# Import Complete.
#
# Importing Be Yourself by Audioslave...
# Import Complete.
#
# Importing Before I Forget by Slipknot...
# Import Complete.
#
# Importing Behind Blue Eyes by The Who...
# Import Complete.
#
# Importing Berzerk by Eminem...
# Import Complete.
#
# Importing Beverly Hills by Weezer...
# Import Complete.
#
# Importing Big Gun by AC/DC...
# Import Complete.
#
# Importing Black Steel in the Hour of Chaos by Public Enemy...
# Import Complete.
#
# Importing Blackout by Linkin Park...
# Import Complete.
#
# Importing Bleed It Out by Linkin Park...
# Import Complete.
#
# Importing Bloodstream by Ed Sheeran...
# Import Complete.
#
# Importing Born Free by Kid Rock...
# Import Complete.
#
# Importing Breaking the Girl by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Bring the Noise by Public Enemy...
# Import Complete.
#
# Importing Broken, Beat & Scarred by Metallica...
# Import Complete.
#
# Importing Burn It Down by Linkin Park...
# Import Complete.
#
# Importing Burning in the Skies by Linkin Park...
# Import Complete.
#
# Importing By the Way by Red Hot Chili Peppers...
# Import Complete.
#
# Importing B.Y.O.B. by System of a Down...
# Import Complete.
#
# Importing Californication by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Castle of Glass by Linkin Park...
# Import Complete.
#
# Importing The Catalyst by Linkin Park...
# Import Complete.
#
# Importing Charlie by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Chop Suey! by System of a Down...
# Import Complete.
#
# Importing Cochise by Audioslave...
# Import Complete.
#
# Importing Coffee Shop by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Cover You in Oil by AC/DC...
# Import Complete.
#
# Importing Cyanide by Metallica...
# Import Complete.
#
# Importing Dani California by Red Hot Chili Peppers...
# Import Complete.
#
# Importing The Day That Never Comes by Metallica...
# Import Complete.
#
# Importing Desecration Smile by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Did I Let You Know by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Dope by Lady Gaga...
# Import Complete.
#
# Importing Dosed by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Dreamin' by Weezer...
# Import Complete.
#
# Importing Duality by Slipknot...
# Import Complete.
#
# Importing End of the Beginning by Black Sabbath...
# Import Complete.
#
# Importing Everybody Knows by Dixie Chicks...
# Import Complete.
#
# Importing Eyes of the Insane by Slayer...
# Import Complete.
#
# Importing Father Stretch My Hands, Pt. 1 by Kanye West...
# Import Complete.
#
# Importing Girls by Beastie Boys...
# Import Complete.
#
# Importing Give It Away by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Given Up by Linkin Park...
# Import Complete.
#
# Importing God Is Dead? by Black Sabbath...
# Import Complete.
#
# Importing Going Back to Cali by LL Cool J...
# Import Complete.
#
# Importing The Greatest Man That Ever Lived (Variations on a Shaker Hymn) by Weezer...
# Import Complete.
#
# Importing Hail Caesar by AC/DC...
# Import Complete.
#
# Importing Hard as a Rock by AC/DC...
# Import Complete.
#
# Importing A Hazy Shade of Winter by Simon & Garfunkel...
# Import Complete.
#
# Importing Heavy Cross by Gossip...
# Import Complete.
#
# Importing Hidden Away by Josh Groban...
# Import Complete.
#
# Importing Higher Window by Josh Groban...
# Import Complete.
#
# Importing Hold It Now, Hit It by Beastie Boys...
# Import Complete.
#
# Importing How I Could Just Kill a Man by Cypress Hill...
# Import Complete.
#
# Importing Hump de Bump by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Hurt by Nine Inch Nails...
# Import Complete.
#
# Importing Hypnotize by System of a Down...
# Import Complete.
#
# Importing I Am the Highway by Audioslave...
# Import Complete.
#
# Importing I Can't Live Without My Radio by LL Cool J...
# Import Complete.
#
# Importing I Hope by Dixie Chicks...
# Import Complete.
#
# Importing If You Have to Ask by Red Hot Chili Peppers...
# Import Complete.
#
# Importing In My Remains by Linkin Park...
# Import Complete.
#
# Importing Innervision by System of a Down...
# Import Complete.
#
# Importing Iridescent by Linkin Park...
# Import Complete.
#
# Importing Jihad by Slayer...
# Import Complete.
#
# Importing The Judas Kiss by Metallica...
# Import Complete.
#
# Importing Kill Rock 'n Roll by System of a Down...
# Import Complete.
#
# Importing Father Stretch My Hands, Pt. 1 by Kanye West...
# Import Complete.
#
# Importing Leave Out All the Rest by Linkin Park...
# Import Complete.
#
# Importing Let Me Give the World to You by Smashing Pumpkins...
# Import Complete.
#
# Importing Lies Greed Misery by Linkin Park...
# Import Complete.
#
# Importing Like a Stone by Audioslave...
# Import Complete.
#
# Importing Lonely Day by System of a Down...
# Import Complete.
#
# Importing Loner by Black Sabbath...
# Import Complete.
#
# Importing The Long Way Around by Dixie Chicks...
# Import Complete.
#
# Importing Look Around by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Lost in the Echo by Linkin Park...
# Import Complete.
#
# Importing Love Long Distance by Gossip...
# Import Complete.
#
# Importing Love Removal Machine by The Cult...
# Import Complete.
#
# Importing The Man Comes Around by Johnny Cash...
# Import Complete.
#
# Importing Mary Jane's Last Dance by Tom Petty and the Heartbreakers...
# Import Complete.
#
# Importing Mary, Mary by The Monkees...
# Import Complete.
#
# Importing Mother by Danzig...
# Import Complete.
#
# Importing My Adidas by Run–D.M.C....
# Import Complete.
#
# Importing My Apocalypse by Metallica...
# Import Complete.
#
# Importing My Friends by Red Hot Chili Peppers...
# Import Complete.
#
# Importing The New Style by Beastie Boys...
# Import Complete.
#
# Importing No More Love by God Lives Underwater...
# Import Complete.
#
# Importing No Sleep till Brooklyn by Beastie Boys...
# Import Complete.
#
# Importing Not Ready to Make Nice by Dixie Chicks...
# Import Complete.
#
# Importing Otherside by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Parallel Universe by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Paul Revere by Beastie Boys...
# Import Complete.
#
# Importing Perfect Situation by Weezer...
# Import Complete.
#
# Importing Powerless by Linkin Park...
# Import Complete.
#
# Importing Question! by System of a Down...
# Import Complete.
#
# Importing Raining Blood by Slayer...
# Import Complete.
#
# Importing Readymade by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Rebel Without A Pause by Public Enemy...
# Import Complete.
#
# Importing Rhyme or Reason by Eminem...
# Import Complete.
#
# Importing Ride by Lana Del Rey...
# Import Complete.
#
# Importing Road Trippin' by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Rock the Bells by LL Cool J...
# Import Complete.
#
# Importing Rolling in the Deep by Adele...
# Import Complete.
#
# Importing The Saints Are Coming by Skids...
# Import Complete.
#
# Importing Scar Tissue by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Sexual Revolution by Macy Gray...
# Import Complete.
#
# Importing Shadow of the Day by Linkin Park...
# Import Complete.
#
# Importing Shallow Be Thy Game by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Show Me How to Live by Audioslave...
# Import Complete.
#
# Importing Silvery Sometimes (Ghosts) by Smashing Pumpkins...
# Import Complete.
#
# Importing Slow Cheetah by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Slumville Sunrise by Jake Bugg...
# Import Complete.
#
# Importing Snow (Hey Oh) by Red Hot Chili Peppers...
# Import Complete.
#
# Importing So Far... by Eminem...
# Import Complete.
#
# Importing Solara by Smashing Pumpkins...
# Import Complete.
#
# Importing Soul to Squeeze by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Spiders by System of a Down...
# Import Complete.
#
# Importing Suck My Kiss by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Sugar by System of a Down...
# Import Complete.
#
# Importing Sweet Child o' Mine by Guns N' Roses...
# Import Complete.
#
# Importing Tell Me Baby by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Tenerife Sea by Ed Sheeran...
# Import Complete.
#
# Importing That Girl by Jennifer Nettles...
# Import Complete.
#
# Importing This Is Such a Pity by Weezer...
# Import Complete.
#
# Importing Toxicity by System of a Down...
# Import Complete.
#
# Importing Ultralight Beam by Kanye West...
# Import Complete.
#
# Importing Under the Bridge by Red Hot Chili Peppers...
# Import Complete.
#
# Importing The Unforgiven by Metallica...
# Import Complete.
#
# Importing Universally Speaking by Red Hot Chili Peppers...
# Import Complete.
#
# Importing Vermilion by Slipknot...
# Import Complete.
#
# Importing Waiting for the End by Linkin Park...
# Import Complete.
#
# Importing Walk This Way by Aerosmith...
# Import Complete.
#
# Importing Walls (Circus) by Tom Petty and the Heartbreakers...
# Import Complete.
#
# Importing Warped by Red Hot Chili Peppers...
# Import Complete.
#
# Importing We Are All on Drugs by Weezer...
# Import Complete.
#
# Importing What Doesn't Kill You by Jake Bugg...
# Import Complete.
#
# Importing What I've Done by Linkin Park...
# Import Complete.
#
# Importing What You Are by Audioslave...
# Import Complete.
#
# Importing Window in the Skies by U2...
# Import Complete.
#
# Importing Wretches and Kings by Linkin Park...
# Import Complete.
#
# Importing You Be Illin'  by Run–D.M.C....
# Import Complete.
#
# Importing You Don't Know How It Feels by Tom Petty...
# Import Complete.
#
# Importing (You Gotta) Fight for Your Right (To Party!) by Beastie Boys...
# Import Complete.
#
# Importing You Wreck Me by Tom Petty...
# Import Complete.
#
# Importing Your Time Has Come by Audioslave...
# Import Complete.
#
# Importing The Zephyr Song by Red Hot Chili Peppers...
# Import Complete.
#
# --------------------
# PRODUCER: Brian Eno
# --------------------
#
# Scraping Wikipedia
# Scraping Wikipedia
#
# Querying Spotify API
#
# Example data:
# ('4th of July', 'U2', 'The Unforgettable Fire', '2c343Y5TmH6jCs3ES9kxjp', '4th Of July - Remastered 2009', 'U2')
# ('42', 'Coldplay', 'Viva la Vida or Death and All His Friends', '2i2Lz3FDIqYdsJZEWkEaTC', '42', 'Coldplay')
# ('Bad', 'U2', 'The Unforgettable Fire', '3fOsKEaGwhp9TRgJnrMA2z', 'Bad - Edit', 'U2')
# ('Be Stiff', 'Devo', 'Devo singles chronology', '6Owohd92bClr5WbzhbL8IM', 'Be Stiff - 2010 Remaster', 'DEVO')
# ('Beautiful Day', 'U2', "All That You Can't Leave Behind", '1VuBmEauSZywQVtqbxNqka', 'Beautiful Day', 'U2')
#
# Extracting Audio Analysis...
#
# Importing 4th of July by U2...
# Import Complete.
#
# Importing 42 by Coldplay...
# Import Complete.
#
# Importing Bad by U2...
# Import Complete.
#
# Importing Be Stiff by Devo...
# Import Complete.
#
# Importing Beautiful Day by U2...
# Import Complete.
#
# Importing Born Under Punches (The Heat Goes On) by Talking Heads...
# Import Complete.
#
# Importing Bullet the Blue Sky by U2...
# Import Complete.
#
# Importing Sail Across the Water by Jane Siberry...
# Import Complete.
#
# Importing Cedars of Lebanon by U2...
# Import Complete.
#
# Importing Cemeteries of London by Coldplay...
# Import Complete.
#
# Importing Christmas Lights by Coldplay...
# Import Complete.
#
# Importing Cities by Talking Heads...
# Import Complete.
#
# Importing Crosseyed and Painless by Talking Heads...
# Import Complete.
#
# Importing Death and All His Friends by Coldplay...
# Import Complete.
#
# Importing Elevation by U2...
# Import Complete.
#
# Importing Even Better Than the Real Thing by U2...
# Import Complete.
#
# Importing Exit by U2...
# Import Complete.
#
# Importing Father and Daughter by Paul Simon...
# Import Complete.
#
# Importing Fez – Being Born by U2...
# Import Complete.
#
# Importing Get On Your Boots by U2...
# Import Complete.
#
# Importing Glass of Water by Coldplay...
# Import Complete.
#
# Importing The Hearts Filthy Lesson by David Bowie...
# Import Complete.
#
# Importing Heaven by Talking Heads...
# Import Complete.
#
# Importing Houses in Motion by Talking Heads...
# Import Complete.
#
# Importing (I Can't Get No) Satisfaction by The Rolling Stones...
# Import Complete.
#
# Importing I Know What I'm Here For by James...
# Import Complete.
#
# Importing I Still Haven't Found What I'm Looking For by U2...
# Import Complete.
#
# Importing I Zimbra by Talking Heads...
# Import Complete.
#
# Importing In a Little While by U2...
# Import Complete.
#
# Importing In God's Country by U2...
# Import Complete.
#
# Importing Jocko Homo by Devo...
# Import Complete.
#
# Importing Kite by U2...
# Import Complete.
#
# Importing Laid by James...
# Import Complete.
#
# Importing Lemon by U2...
# Import Complete.
#
# Importing Life During Wartime by Talking Heads...
# Import Complete.
#
# Importing Life in Technicolor ii by Coldplay...
# Import Complete.
#
# Importing Lost! by Coldplay...
# Import Complete.
#
# Importing Magnificent by U2...
# Import Complete.
#
# Importing MLK by U2...
# Import Complete.
#
# Importing Moment of Surrender by U2...
# Import Complete.
#
# Importing Mongoloid by Devo...
# Import Complete.
#
# Importing Mothers of the Disappeared by U2...
# Import Complete.
#
# Importing Mysterious Ways by U2...
# Import Complete.
#
# Importing New York by U2...
# Import Complete.
#
# Importing No Line on the Horizon by U2...
# Import Complete.
#
# Importing Numb by U2...
# Import Complete.
#
# Importing Once in a Lifetime by Talking Heads...
# Import Complete.
#
# Importing One by U2...
# Import Complete.
#
# Importing One Tree Hill by U2...
# Import Complete.
#
# Importing Paradise by Coldplay...
# Import Complete.
#
# Importing Peace on Earth by U2...
# Import Complete.
#
# Importing Pride (In the Name of Love) by U2...
# Import Complete.
#
# Importing Red Hill Mining Town by U2...
# Import Complete.
#
# Importing Running to Stand Still by U2...
# Import Complete.
#
# Importing Slug by Passengers...
# Import Complete.
#
# Importing Stand Up Comedy by U2...
# Import Complete.
#
# Importing Strangers When We Meet by David Bowie...
# Import Complete.
#
# Importing Strawberry Swing by Coldplay...
# Import Complete.
#
# Importing Stuck in a Moment You Can't Get Out Of by U2...
# Import Complete.
#
# Importing Sweetest Thing by U2...
# Import Complete.
#
# Importing Take Me to the River by Al Green...
# Import Complete.
#
# Importing Trip Through Your Wires by U2...
# Import Complete.
#
# Importing Tryin' to Throw Your Arms Around the World by U2...
# Import Complete.
#
# Importing The Unforgettable Fire by U2...
# Import Complete.
#
# Importing Unknown Caller by U2...
# Import Complete.
#
# Importing Until the End of the World by U2...
# Import Complete.
#
# Importing Violet Hill by Coldplay...
# Import Complete.
#
# Importing Viva la Vida by Coldplay...
# Import Complete.
#
# Importing Walk On by U2...
# Import Complete.
#
# Importing When I Look at the World by U2...
# Import Complete.
#
# Importing Where the Streets Have No Name by U2...
# Import Complete.
#
# Importing White as Snow by U2...
# Import Complete.
#
# Importing Wild Honey by U2...
# Import Complete.
#
# Importing With or Without You by U2...
# Import Complete.
#
# Importing Yes by Coldplay...
# Import Complete.
#
# Importing Your Blue Room by Passengers...
# Import Complete.
#
# Importing Zooropa by U2...
# Import Complete.
#
# --------------------
# PRODUCER: Stock Aitken Waterman
# --------------------
#
# Scraping Wikipedia
# Scraping Wikipedia
#
# Querying Spotify API
#
# Example data:
# ('All of Me (Boy Oh Boy)', 'Sabrina', 'Super Sabrina', '64kn6qDvcDmekwIlicy0n6', 'All of Me - The Boy Oh Boy Mix', 'Sabrina')
# ('Better the Devil You Know', 'Kylie Minogue', 'Rhythm of Love', '3dpvfWZYPcPGz8vRZN2yUt', 'Better the Devil You Know', 'Kylie Minogue')
# ('Beyond Your Wildest Dreams', 'Lonnie Gordon', 'If I Have to Stand Alone', '2N2na3Dmn5cC3GCyjj3pQG', 'Beyond Your Wildest Dreams', 'Lonnie Gordon')
# ('Brand New Lover', 'Dead or Alive', 'Mad, Bad, and Dangerous to Know', '4JO49IxCMeGdWVtBU5ESAO', 'Brand New Lover - Edit', 'Dead Or Alive')
# ('Breakaway', 'Donna Summer', 'Another Place and Time', '4UhU08qC0KQZWMtDw5L1rk', 'Breakaway', 'Donna Summer')
#
# Extracting Audio Analysis...
#
# Importing All of Me (Boy Oh Boy) by Sabrina...
# Import Complete.
#
# Importing Better the Devil You Know by Kylie Minogue...
# Import Complete.
#
# Importing Beyond Your Wildest Dreams by Lonnie Gordon...
# Import Complete.
#
# Importing Brand New Lover by Dead or Alive...
# Import Complete.
#
# Importing Breakaway by Donna Summer...
# Import Complete.
#
# Importing Cross My Broken Heart by Sinitta...
# Import Complete.
#
# Importing The End of the World by Skeeter Davis...
# Import Complete.
#
# Importing Every Day (I Love You More) by Jason Donovan...
# Import Complete.
#
# Importing Ferry Cross the Mersey by Gerry and the Pacemakers...
# Import Complete.
#
# Importing F.L.M. by Mel and Kim...
# Import Complete.
#
# Importing Give Me Just a Little More Time by Chairmen of the Board...
# Import Complete.
#
# Importing Good Times with Bad Boys by Boy Krazy...
# Import Complete.
#
# Importing Got to Be Certain by Kylie Minogue...
# Import Complete.
#
# Importing Hand on Your Heart by Kylie Minogue...
# Import Complete.
#
# Importing Happenin' All Over Again by Lonnie Gordon...
# Import Complete.
#
# Importing The Harder I Try by Brother Beyond...
# Import Complete.
#
# Importing I Can't Help It by Bananarama...
# Import Complete.
#
# Importing I Don't Wanna Get Hurt by Donna Summer...
# Import Complete.
#
# Importing I Heard A Rumour by Bananarama...
# Import Complete.
#
# Importing I Just Don't Have the Heart by Cliff Richard...
# Import Complete.
#
# Importing I Only Want to Be with You by Dusty Springfield...
# Import Complete.
#
# Importing I Should Be So Lucky by Kylie Minogue...
# Import Complete.
#
# Importing I Want You Back by Bananarama...
# Import Complete.
#
# Importing In Another Place And Time by Donna Summer...
# Import Complete.
#
# Importing In Love With Love by Debbie Harry...
# Import Complete.
#
# Importing In Too Deep by Dead or Alive...
# Import Complete.
#
# Importing It Would Take a Strong Strong Man by Rick Astley...
# Import Complete.
#
# Importing Je ne sais pas pourquoi by Kylie Minogue...
# Import Complete.
#
# Importing Listen to Your Heart by Sonia...
# Import Complete.
#
# Importing The Loco-Motion by Little Eva...
# Import Complete.
#
# Importing Love in the First Degree by Bananarama...
# Import Complete.
#
# Importing Love, Truth and Honesty by Bananarama...
# Import Complete.
#
# Importing Lover Come Back to Me by Dead or Alive...
# Import Complete.
#
# Importing Make It Easy on Me by Sybil...
# Import Complete.
#
# Importing More Than Physical by Bananarama...
# Import Complete.
#
# Importing My Heart Goes Bang (Get Me to the Doctor) by Dead or Alive...
# Import Complete.
#
# Importing Nathan Jones by The Supremes...
# Import Complete.
#
# Importing Never Gonna Give You Up by Rick Astley...
# Import Complete.
#
# Importing Never Too Late by Kylie Minogue...
# Import Complete.
#
# Importing Respectable by Mel and Kim...
# Import Complete.
#
# Importing Say I'm Your Number One by Princess...
# Import Complete.
#
# Importing Shattered Glass by Laura Branigan...
# Import Complete.
#
# Importing Shocked by Kylie Minogue...
# Import Complete.
#
# Importing Showing Out (Get Fresh at the Weekend) by Mel and Kim...
# Import Complete.
#
# Importing Step Back in Time by Kylie Minogue...
# Import Complete.
#
# Importing Take Me to Your Heart by Rick Astley...
# Import Complete.
#
# Importing Tears on My Pillow by Little Anthony and the Imperials...
# Import Complete.
#
# Importing (Tell Me) She Means Nothing to You At All by La Toya Jackson...
# Import Complete.
#
# Importing This Time I Know It's for Real by Donna Summer...
# Import Complete.
#
# Importing Together Forever by Rick Astley...
# Import Complete.
#
# Importing Too Many Broken Hearts by Jason Donovan...
# Import Complete.
#
# Importing Toy Boy by Sinitta...
# Import Complete.
#
# Importing Turn It into Love by Kylie Minogue...
# Import Complete.
#
# Importing Venus by Shocking Blue...
# Import Complete.
#
# Importing What Do I Have to Do by Kylie Minogue...
# Import Complete.
#
# Importing Whatever I Do (Wherever I Go) by Hazell Dean...
# Import Complete.
#
# Importing When Love Takes Over You by Donna Summer...
# Import Complete.
#
# Importing When You Come Back to Me by Jason Donovan...
# Import Complete.
#
# Importing Who's Leaving Who by Anne Murray...
# Import Complete.
#
# Importing Word Is Out by Kylie Minogue...
# Import Complete.
#
# Importing You Spin Me Round (Like a Record) by Dead or Alive...
# Import Complete.
#
# Importing You Think You're a Man by Divine...
# Import Complete.

# %%
collection.count_documents(filter={})
# Out:
# 467

# %%
list(collection.aggregate(
   [{"$group" : { "_id" : '$producer', "count" : {"$sum" : 1}}}]
))
# Out:
# [{'_id': 'Stock Aitken Waterman', 'count': 62},
#  {'_id': 'George Martin', 'count': 130},
#  {'_id': 'Dr. Dre', 'count': 43},
#  {'_id': 'Rick Rubin', 'count': 155},
#  {'_id': 'Brian Eno', 'count': 77}]

# %% [markdown]
# It looks like a good amount of Dr. Dre and SAW songs are missing... I wonder why...

# %%
idx_list = load_producers(['https://en.wikipedia.org/w/index.php?title=Category:Song_recordings_produced_by_George_Martin&pagefrom=Ob-La-Di%2C+Ob-La-Da#mw-pages'], collection, sp)
# Out:
# --------------------
# PRODUCER: George Martin
# --------------------
#
# Scraping Wikipedia
# Scraping Wikipedia
#
# Querying Spotify API
#
# Example data:
# ('Ob-La-Di, Ob-La-Da', 'the Beatles', 'The Beatles', '1gFNm7cXfG1vSMcxPpSxec', 'Ob-La-Di, Ob-La-Da - Remastered 2009', 'The Beatles')
# ("Octopus's Garden", 'the Beatles', 'Abbey Road', '47Yv8Plq2mBXwdGq4PVFDR', "Octopus' Garden", 'The Beatles Revival Band & Orchestra')
# ('Oh! Darling', 'the Beatles', 'Abbey Road', '2mxByJWOajjiVsLWjNXvDJ', 'Oh! Darling - Remastered 2009', 'The Beatles')
# ('Only a Northern Song', 'the Beatles', 'Yellow Submarine', '4phXWLTSlC1BEogSWhJMDD', 'Only A Northern Song - Remastered 2009', 'The Beatles')
# ('P.S. I Love You', 'the Beatles', 'Please Please Me', '7Msq9qojB7yORuJvz49iUy', 'P.S. I Love You - Remastered 2009', 'The Beatles')
#
# Extracting Audio Analysis...
#
# Importing Ob-La-Di, Ob-La-Da by the Beatles...
# Import Complete.
#
# Importing Octopus's Garden by the Beatles...
# Import Complete.
#
# Importing Oh! Darling by the Beatles...
# Import Complete.
#
# Importing Only a Northern Song by the Beatles...
# Import Complete.
#
# Importing P.S. I Love You by the Beatles...
# Import Complete.
#
# Importing Paperback Writer by the Beatles...
# Import Complete.
#
# Importing Penny Lane by the Beatles...
# Import Complete.
#
# Importing Pepperland by George Martin...
# Import Complete.
#
# Importing Piggies by the Beatles...
# Import Complete.
#
# Importing Pipes of Peace by Paul McCartney...
# Import Complete.
#
# Importing Please Mr. Postman by The Marvelettes...
# Import Complete.
#
# Importing Please Please Me by the Beatles...
# Import Complete.
#
# Importing Polythene Pam by the Beatles...
# Import Complete.
#
# Importing Rain by the Beatles...
# Import Complete.
#
# Importing Reap the Wild Wind by Ultravox...
# Import Complete.
#
# Importing The Reason by Celine Dion...
# Import Complete.
#
# Importing Revolution 9 by the Beatles...
# Import Complete.
#
# Importing Rock and Roll Music by Chuck Berry...
# Import Complete.
#
# Importing Rocky Raccoon by the Beatles...
# Import Complete.
#
# Importing Roll Over Beethoven by Chuck Berry...
# Import Complete.
#
# Importing Run for Your Life by the Beatles...
# Import Complete.
#
# Importing Savoy Truffle by the Beatles...
# Import Complete.
#
# Importing Sea of Holes by George Martin...
# Import Complete.
#
# Importing Sea of Monsters by George Martin...
# Import Complete.
#
# Importing Sea of Time by George Martin...
# Import Complete.
#
# Importing Sexy Sadie by the Beatles...
# Import Complete.
#
# Importing Sgt. Pepper’s Lonely Hearts Club Band by the Beatles...
# Import Complete.
#
# Importing Sgt. Pepper’s Lonely Hearts Club Band by the Beatles...
# Import Complete.
#
# Importing She Came In Through the Bathroom Window by the Beatles...
# Import Complete.
#
# Importing She Said She Said by the Beatles...
# Import Complete.
#
# Importing She's a Woman by the Beatles...
# Import Complete.
#
# Importing She's Leaving Home by the Beatles...
# Import Complete.
#
# Importing Since I Lost My Baby by The Temptations...
# Import Complete.
#
# Importing Sister Golden Hair by America...
# Import Complete.
#
# Importing Something by the Beatles...
# Import Complete.
#
# Importing Something Tells Me (Something's Gonna Happen Tonight) by Cilla Black...
# Import Complete.
#
# Importing Step Inside Love by Cilla Black...
# Import Complete.
#
# Importing Stop This Game by Cheap Trick...
# Import Complete.
#
# Importing Strawberry Fields Forever by the Beatles...
# Import Complete.
#
# Importing Sun King by the Beatles...
# Import Complete.
#
# Importing Surround Yourself with Sorrow by Cilla Black...
# Import Complete.
#
# Importing Take It Away by Paul McCartney...
# Import Complete.
#
# Importing Take It Easy on Me by Little River Band...
# Import Complete.
#
# Importing Taxman by the Beatles...
# Import Complete.
#
# Importing Tell Me What You See by the Beatles...
# Import Complete.
#
# Importing Tell Me Why by the Beatles...
# Import Complete.
#
# Importing That Means a Lot by the Beatles...
# Import Complete.
#
# Importing Things We Said Today by the Beatles...
# Import Complete.
#
# Importing Think for Yourself by the Beatles...
# Import Complete.
#
# Importing Ticket to Ride by the Beatles...
# Import Complete.
#
# Importing Tin Man by America...
# Import Complete.
#
# Importing Tomb of the Unknown Love by Kenny Rogers...
# Import Complete.
#
# Importing Tomorrow Never Knows by the Beatles...
# Import Complete.
#
# Importing Tug of War by Paul McCartney...
# Import Complete.
#
# Importing Visions in Blue by Ultravox...
# Import Complete.
#
# Importing Wait by the Beatles...
# Import Complete.
#
# Importing Walk Hand in Hand by Tony Martin...
# Import Complete.
#
# Importing We Came to Dance by Ultravox...
# Import Complete.
#
# Importing We Can Work It Out by the Beatles...
# Import Complete.
#
# Importing What Goes On by the Beatles...
# Import Complete.
#
# Importing What You're Doing by the Beatles...
# Import Complete.
#
# Importing What's the New Mary Jane by the Beatles...
# Import Complete.
#
# Importing When I Get Home by the Beatles...
# Import Complete.
#
# Importing When I'm Sixty-Four by the Beatles...
# Import Complete.
#
# Importing While My Guitar Gently Weeps by the Beatles...
# Import Complete.
#
# Importing Why Don't We Do It in the Road? by the Beatles...
# Import Complete.
#
# Importing Wild Honey Pie by the Beatles...
# Import Complete.
#
# Importing With a Little Help from My Friends by the Beatles...
# Import Complete.
#
# Importing Within You Without You by the Beatles...
# Import Complete.
#
# Importing The Word by the Beatles...
# Import Complete.
#
# Importing Words of Love by Buddy Holly...
# Import Complete.
#
# Importing Yellow Submarine by the Beatles...
# Import Complete.
#
# Importing Yer Blues by the Beatles...
# Import Complete.
#
# Importing Yes It Is by the Beatles...
# Import Complete.
#
# Importing Yesterday by the Beatles...
# Import Complete.
#
# Importing You Can't Do That by the Beatles...
# Import Complete.
#
# Importing You Know My Name(Look Up the Number) by the Beatles...
# Import Complete.
#
# Importing You Know What to Do by the Beatles...
# Import Complete.
#
# Importing You Like Me Too Much by the Beatles...
# Import Complete.
#
# Importing You Never Give Me Your Money by the Beatles...
# Import Complete.
#
# Importing You Won't See Me by the Beatles...
# Import Complete.
#
# Importing You've Lost That Lovin' Feelin' by The Righteous Brothers...
# Import Complete.
#
# Importing Your Mother Should Know by the Beatles...
# Import Complete.
